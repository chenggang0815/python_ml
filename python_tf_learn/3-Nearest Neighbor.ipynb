# %%
import tensorflow as tf
import numpy as np

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('/tmp/data',one_hot=True)
# Out:
# /Users/chenggang/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/chenggang/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# WARNING:tensorflow:From <ipython-input-1-062d41b7bcf9>:5: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/chenggang/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /Users/chenggang/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /Users/chenggang/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /Users/chenggang/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/chenggang/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/chenggang/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
Xtr, Ytr = mnist.train.next_batch(5000) #5000 for training (nn candidates)
Xte, Yte = mnist.test.next_batch(200) #200 for testing

# %%
xtr = tf.placeholder(tf.float32,[None,784])
xte = tf.placeholder(tf.float32,[784])

# %%
distance = tf.reduce_sum(tf.abs(tf.add(xtr,tf.negative(xte))),reduction_indices=1)

pred = tf.argmin(distance,0)

accuarcy = 0

init = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    sess.run(init)
    
    for i in range(len(Xte)):
        nn_index=sess.run(pred,feed_dict={xtr:Xtr,xte:Xte[i,:]})
        # Get nearest neighbor class label and compare it to its true label
        print("Test",i,"Prediction:",np.argmax(Ytr[nn_index])),\
        "True class:",np.argmax(Yte[i])
        # Calculate accuracy
        if np.argmax(Ytr[nn_index]) == np.argmax(Yte[i]):
            accuarcy += 1./len(Xte)
    print("Done!")
    print("Accuracy:", accuarcy)
# Out:
# Test 0 Prediction: 0
# Test 1 Prediction: 0
# Test 2 Prediction: 4
# Test 3 Prediction: 4
# Test 4 Prediction: 2
# Test 5 Prediction: 2
# Test 6 Prediction: 2
# Test 7 Prediction: 9
# Test 8 Prediction: 1
# Test 9 Prediction: 7
# Test 10 Prediction: 7
# Test 11 Prediction: 8
# Test 12 Prediction: 6
# Test 13 Prediction: 4
# Test 14 Prediction: 7
# Test 15 Prediction: 9
# Test 16 Prediction: 9
# Test 17 Prediction: 8
# Test 18 Prediction: 4
# Test 19 Prediction: 6
# Test 20 Prediction: 3
# Test 21 Prediction: 1
# Test 22 Prediction: 3
# Test 23 Prediction: 2
# Test 24 Prediction: 4
# Test 25 Prediction: 7
# Test 26 Prediction: 5
# Test 27 Prediction: 5
# Test 28 Prediction: 9
# Test 29 Prediction: 2
# Test 30 Prediction: 3
# Test 31 Prediction: 9
# Test 32 Prediction: 8
# Test 33 Prediction: 6
# Test 34 Prediction: 9
# Test 35 Prediction: 5
# Test 36 Prediction: 1
# Test 37 Prediction: 1
# Test 38 Prediction: 6
# Test 39 Prediction: 0
# Test 40 Prediction: 0
# Test 41 Prediction: 7
# Test 42 Prediction: 4
# Test 43 Prediction: 3
# Test 44 Prediction: 4
# Test 45 Prediction: 5
# Test 46 Prediction: 6
# Test 47 Prediction: 1
# Test 48 Prediction: 6
# Test 49 Prediction: 3
# Test 50 Prediction: 3
# Test 51 Prediction: 1
# Test 52 Prediction: 0
# Test 53 Prediction: 9
# Test 54 Prediction: 9
# Test 55 Prediction: 0
# Test 56 Prediction: 7
# Test 57 Prediction: 1
# Test 58 Prediction: 9
# Test 59 Prediction: 9
# Test 60 Prediction: 3
# Test 61 Prediction: 4
# Test 62 Prediction: 8
# Test 63 Prediction: 9
# Test 64 Prediction: 7
# Test 65 Prediction: 3
# Test 66 Prediction: 8
# Test 67 Prediction: 5
# Test 68 Prediction: 7
# Test 69 Prediction: 3
# Test 70 Prediction: 6
# Test 71 Prediction: 2
# Test 72 Prediction: 0
# Test 73 Prediction: 0
# Test 74 Prediction: 3
# Test 75 Prediction: 4
# Test 76 Prediction: 3
# Test 77 Prediction: 2
# Test 78 Prediction: 6
# Test 79 Prediction: 9
# Test 80 Prediction: 3
# Test 81 Prediction: 7
# Test 82 Prediction: 3
# Test 83 Prediction: 1
# Test 84 Prediction: 2
# Test 85 Prediction: 2
# Test 86 Prediction: 5
# Test 87 Prediction: 1
# Test 88 Prediction: 1
# Test 89 Prediction: 9
# Test 90 Prediction: 9
# Test 91 Prediction: 5
# Test 92 Prediction: 0
# Test 93 Prediction: 5
# Test 94 Prediction: 1
# Test 95 Prediction: 7
# Test 96 Prediction: 7
# Test 97 Prediction: 0
# Test 98 Prediction: 0
# Test 99 Prediction: 0
# Test 100 Prediction: 2
# Test 101 Prediction: 0
# Test 102 Prediction: 8
# Test 103 Prediction: 0
# Test 104 Prediction: 5
# Test 105 Prediction: 2
# Test 106 Prediction: 7
# Test 107 Prediction: 2
# Test 108 Prediction: 6
# Test 109 Prediction: 9
# Test 110 Prediction: 2
# Test 111 Prediction: 1
# Test 112 Prediction: 3
# Test 113 Prediction: 5
# Test 114 Prediction: 0
# Test 115 Prediction: 0
# Test 116 Prediction: 8
# Test 117 Prediction: 0
# Test 118 Prediction: 8
# Test 119 Prediction: 5
# Test 120 Prediction: 9
# Test 121 Prediction: 6
# Test 122 Prediction: 5
# Test 123 Prediction: 7
# Test 124 Prediction: 6
# Test 125 Prediction: 8
# Test 126 Prediction: 4
# Test 127 Prediction: 7
# Test 128 Prediction: 3
# Test 129 Prediction: 2
# Test 130 Prediction: 0
# Test 131 Prediction: 6
# Test 132 Prediction: 3
# Test 133 Prediction: 3
# Test 134 Prediction: 0
# Test 135 Prediction: 4
# Test 136 Prediction: 1
# Test 137 Prediction: 5
# Test 138 Prediction: 9
# Test 139 Prediction: 0
# Test 140 Prediction: 0
# Test 141 Prediction: 9
# Test 142 Prediction: 1
# Test 143 Prediction: 0
# Test 144 Prediction: 0
# Test 145 Prediction: 2
# Test 146 Prediction: 1
# Test 147 Prediction: 3
# Test 148 Prediction: 2
# Test 149 Prediction: 9
# Test 150 Prediction: 4
# Test 151 Prediction: 0
# Test 152 Prediction: 7
# Test 153 Prediction: 7
# Test 154 Prediction: 3
# Test 155 Prediction: 6
# Test 156 Prediction: 3
# Test 157 Prediction: 8
# Test 158 Prediction: 6
# Test 159 Prediction: 6
# Test 160 Prediction: 5
# Test 161 Prediction: 7
# Test 162 Prediction: 9
# Test 163 Prediction: 9
# Test 164 Prediction: 1
# Test 165 Prediction: 8
# Test 166 Prediction: 0
# Test 167 Prediction: 2
# Test 168 Prediction: 8
# Test 169 Prediction: 0
# Test 170 Prediction: 8
# Test 171 Prediction: 7
# Test 172 Prediction: 7
# Test 173 Prediction: 5
# Test 174 Prediction: 8
# Test 175 Prediction: 4
# Test 176 Prediction: 6
# Test 177 Prediction: 2
# Test 178 Prediction: 5
# Test 179 Prediction: 6
# Test 180 Prediction: 7
# Test 181 Prediction: 9
# Test 182 Prediction: 9
# Test 183 Prediction: 8
# Test 184 Prediction: 9
# Test 185 Prediction: 1
# Test 186 Prediction: 3
# Test 187 Prediction: 5
# Test 188 Prediction: 4
# Test 189 Prediction: 5
# Test 190 Prediction: 3
# Test 191 Prediction: 9
# Test 192 Prediction: 0
# Test 193 Prediction: 9
# Test 194 Prediction: 0
# Test 195 Prediction: 7
# Test 196 Prediction: 6
# Test 197 Prediction: 3
# Test 198 Prediction: 7
# Test 199 Prediction: 1
# Done!
# Accuracy: 1.829999999999983

# %%
Xte.shape
# Out:
# (200, 784)

# %%
a = tf.Variable([[1,2,3,4],[1,9,1,1],[2,2,2,2]])
b = tf.Variable([[2,3,4,4],[1,1,1,1],[0,0,0,0]])
d = tf.reduce_sum(tf.abs(tf.add(a,tf.negative(b))),reduction_indices=1)
pred = tf.argmin(d,0)
sess = tf.Session()
sess.run(tf.global_variables_initializer())
print(sess.run(d))
print(sess.run(pred))
# Out:
# [3 8 8]
# 0
